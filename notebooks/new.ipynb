# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(60, 3840, 60)
loss = [
    8.637400, 3.487500, 1.895200, 1.094500, 0.712400, 0.465100, 0.373500, 0.322300,
    0.274300, 0.296700, 0.163100, 0.168300, 0.196700, 0.130300, 0.114200, 0.112300,
    0.085200, 0.073200, 0.074700, 0.078600, 0.077100, 0.053000, 0.082800, 0.058200,
    0.053000, 0.059500, 0.050900, 0.040400, 0.043100, 0.043800, 0.045600, 0.050300,
    0.045400, 0.039000, 0.045700, 0.036700, 0.049600, 0.038800, 0.042900, 0.026300,
    0.029800, 0.034900, 0.037700, 0.031800, 0.032200, 0.028300, 0.029800, 0.030100,
    0.021500, 0.026600, 0.030000, 0.017400, 0.022600, 0.021500, 0.020300, 0.018500,
    0.019900, 0.023100, 0.023700, 0.021300, 0.021100, 0.018400, 0.018700
]

plt.figure(figsize=(10, 6))
plt.plot(steps, loss, marker='o')
plt.title('Training Loss albert-model')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
